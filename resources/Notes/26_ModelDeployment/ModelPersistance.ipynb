# %% [markdown]
# # Model Persistance with Scikit-Learn

# %%
import pandas as pd

# %%
df=pd.read_csv('../../jupyter_notebooks/DATA/Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
X=df.drop('sales',axis=1)
y=df['sales']

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# You want to split into 3 sets: train, validation and hold out.
#
# First split will be train/rest; may be 70-30%
#
# Second sprint will be dividing the rest (the 30% of the total) into test/hold out, may be in equal parts (50-50%) or more to validation if data is scarse.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_validation, X_holdout_test, y_validation, y_hold_out_test = train_test_split(X_test, y_test, test_size=0.5, random_state=101)

# %%
len(X_train)
# Out:
# 140

# %%
len(X)
# Out:
# 200

# %%
len(X_holdout_test)
# Out:
# 30

# %%
len(X_validation)
# Out:
# 30

# %% [markdown]
# ## Model Training

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor(n_estimators=3,random_state=101)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=3, random_state=101)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
validation_predictions=model.predict(X_validation)

# %%
mean_absolute_error(y_validation,validation_predictions)
# Out:
# 0.853333333333333

# %%
mean_squared_error(y_validation,validation_predictions)**0.5
# Out:
# 1.1031268688998959

# %%
df.describe()['sales']
# Out:
# count    200.000000
# mean      14.022500
# std        5.217457
# min        1.600000
# 25%       10.375000
# 50%       12.900000
# 75%       17.400000
# max       27.000000
# Name: sales, dtype: float64

# %% [markdown]
# Let's assume that we are not satisfied with the result (let's tune some hyperparameters)

# %%
model30=RandomForestRegressor(n_estimators=30,random_state=101)

# %%
model30.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=30, random_state=101)

# %%
validation_predictions30=model30.predict(X_validation)

# %%
mean_absolute_error(y_validation,validation_predictions30)
# Out:
# 0.6575555555555552

# %% [markdown]
# From 0.85333 with 3 estimators, we have gone down to 0.657555 with 30.

# %%
mean_squared_error(y_validation,validation_predictions30)**0.5
# Out:
# 0.8542009478215644

# %% [markdown]
# From 1.103127 we have gone down to 0.85420

# %% [markdown]
# We have improved and, let's say we are satisfied. We have to check the model with data it has not seen: hold out set. This is going to be how the model is going to perform in real world with unseen data.

# %% [markdown]
# ### Final performance metrics

# %%
holdout_predictions=model30.predict(X_holdout_test)

# %%
mean_absolute_error(y_hold_out_test,holdout_predictions)
# Out:
# 0.5937777777777775

# %%
mean_squared_error(y_hold_out_test,holdout_predictions)**0.5
# Out:
# 0.745323693040418

# %%
final_model=RandomForestRegressor(n_estimators=30,random_state=101)

# %%
final_model.fit(X,y)
# Out:
# RandomForestRegressor(n_estimators=30, random_state=101)

# %%
import joblib

# %%
# save the model, so can be reused.
joblib.dump(final_model,'final_model.pkl')
# Out:
# ['final_model.pkl']

# %% [markdown]
# You should also save the columns from your training data, in the order you used them to train the model

# %%
list(X.columns)
# Out:
# ['TV', 'radio', 'newspaper']

# %%
joblib.dump(list(X.columns),'col_names.pkl')
# Out:
# ['col_names.pkl']

# %% [markdown]
# ## Test the saved model
# Now let's check that we can use the model from the files we just saved.

# %%
new_columns = joblib.load('col_names.pkl')

# %%
new_columns
# Out:
# ['TV', 'radio', 'newspaper']

# %%
loaded_model=joblib.load('final_model.pkl')

# %%
loaded_model.predict([[230.1,37.8,69.2]])
# Out:
# C:\Users\mvgarcia\.conda\envs\PythonMLandDS\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([21.99])

# %% [markdown]
# That is actually quite close to the original value (22.1) of the first row of data, that we just used.

# %% [markdown]
# # Making the model available to anyone
# Now that the model is persisted, what we need is some way to provide it as an API or available service that anyone can use to predict with new data.
#
# We are going to wrap the ML model with a Flask library for python.
#
# Then one can POST new data and then GET the results of predicting with the model the result for that new data.
