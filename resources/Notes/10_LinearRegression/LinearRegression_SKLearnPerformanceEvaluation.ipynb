# %% [markdown]
# # Performance evaluation
# How to decide if the model predictions are accurate.
#
# Mean Absolute Error -> just account for the distance of each prediction to the real value
# Mean Squared Error -> instead of absolute value, calculates the square of the distance; it then penalises more the bigger distances.
# Root Mean Square Error -> takes the square root of the Mean Squared Error, so the resulting units are the original ones, instea of, for instance, "square dollars."
