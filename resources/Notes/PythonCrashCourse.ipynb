# %% [markdown]
# # Python crash course

# %%
5%2
# Out:
# 1

# %%
5%3
# Out:
# 2

# %%
"strings go in 'single' or 'double' quotes"
# Out:
# "strings go in 'single' or 'double' quotes"

# %%
print('hello')
# Out:
# hello

# %%
'hello'
# Out:
# 'hello'

# %%
"My name is {} and I live in {} (zip code {}).".format('Manuel', 'Narón', 15570)
# Out:
# 'My name is Manuel and I live in Narón (zip code 15570).'

# %% [markdown]
# ## Lists

# %%
[1,2,3, 'a']
# Out:
# [1, 2, 3, 'a']

# %%
my_list = ['a','b','c','d']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[-1]
# Out:
# 'd'

# %%
my_list[0] = 'A'
my_list
# Out:
# ['A', 'b', 'c', 'd']

# %%
# my_list[4] = 'E'  # ---> error out of range.
my_list
# Out:
# ['A', 'b', 'c', 'd']

# %%
my_list.append('E')

# %%
my_list
# Out:
# ['A', 'b', 'c', 'd', 'E']

# %%
my_list.append(['f','g','h'])
my_list
# Out:
# ['A', 'b', 'c', 'd', 'E', ['f', 'g', 'h']]

# %%
my_list[5]
# Out:
# ['f', 'g', 'h']

# %%
my_list.remove(['f','g','h'])

# %%
my_list
# Out:
# ['A', 'b', 'c', 'd', 'E']

# %%
my_list.extend(['f','g','h'])
my_list
# Out:
# ['A', 'b', 'c', 'd', 'E', 'f', 'g', 'h']

# %%
my_list[5]
# Out:
# 'f'

# %% [markdown]
# ## dictionary
# These do not have order and are designed to be retrieved by key

# %%
dict1 = {'key1':'value1', 'key2':'value2', 'key3':'value3', 'key4':'value4', 'key5':'value5', 'key6':'value6'}
dict1
# Out:
# {'key1': 'value1',
#  'key2': 'value2',
#  'key3': 'value3',
#  'key4': 'value4',
#  'key5': 'value5',
#  'key6': 'value6'}

# %%
dict1['key3']
# Out:
# 'value3'

# %%
dict1.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3', 'key4', 'key5', 'key6'])

# %%
type(dict1.keys())
# Out:
# dict_keys

# %%
dict1.values()
# Out:
# dict_values(['value1', 'value2', 'value3', 'value4', 'value5', 'value6'])

# %%
type(dict1.values())
# Out:
# dict_values

# %%
list(dict1.values())
# Out:
# ['value1', 'value2', 'value3', 'value4', 'value5', 'value6']

# %% [markdown]
# ## Tuples
# They are immutable

# %% [markdown]
# ## Sets
# Unordered collection of elements. No duplicates

# %% [markdown]
# ## Operators

# %%
'A' != 'a'
# Out:
# True

# %%
(1 == 1)
# Out:
# True

# %%
(1 == 1) and ('a' == 'a')
# Out:
# True

# %%
if 1==1:
    print('Yes')
# Out:
# Yes

# %% [markdown]
# ## Control statements

# %%
if 1==2:
    print('Yes')
else:
    print('No')
# Out:
# No

# %%
x = 42 #5 #200
if x < 10:
    print('it is small')
elif x < 100:
    print('it is bigger')
else:
    print('it is BIG')
# Out:
# it is bigger

# %%
x = [1,2,3,4,5]
for i in x:
    print(f'now serving {i}')
# Out:
# now serving 1
# now serving 2
# now serving 3
# now serving 4
# now serving 5

# %%
y = range(1,6)
for i in y:
    print(f'now serving {i}')
# Out:
# now serving 1
# now serving 2
# now serving 3
# now serving 4
# now serving 5

# %%
for i in range(1,6):
    print(f'now serving {i}')
# Out:
# now serving 1
# now serving 2
# now serving 3
# now serving 4
# now serving 5

# %% [markdown]
# ## List comprehension

# %%
x = [1,2,3,4,5]
out = []
for num in x:
    out.append(num**2)

print(out)
# Out:
# [1, 4, 9, 16, 25]

# %%
#Now with list comprehension:
[num**2 for num in x]
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Functions, objects, lambda expressions

# %%
def my_func():
    print('Hello')

# %%
my_func()
# Out:
# Hello

# %%
def my_func(name):
    print(f'Hello, {name}')
my_func('Pepe')
# Out:
# Hello, Pepe

# %%
my_func('Paco')
# Out:
# Hello, Paco

# %%
def my_func(name='you'):
    print(f'Hello, {name}')
my_func('Pepe')
# Out:
# Hello, Pepe

# %%
my_func('Paco')
# Out:
# Hello, Paco

# %%
my_func()
# Out:
# Hello, you

# %%
def square(x):
    return x**2

# %%
result=square(2)

# %%
result
# Out:
# 4

# %% [markdown]
# ### Lambda expressions

# %%
def times_two(var):
    return var*2

# %%
times_two(10)
# Out:
# 20

# %%
lambda var: var*2
# Out:
# <function __main__.<lambda>(var)>

# %%
st = 'Hello, my name is Manuel'

# %%
st.upper()
# Out:
# 'HELLO, MY NAME IS MANUEL'

# %%
st.lower()
# Out:
# 'hello, my name is manuel'

# %%
st.split()
# Out:
# ['Hello,', 'my', 'name', 'is', 'Manuel']

# %%
tweet='Hello #sports'

# %%
tweet.split('#')
# Out:
# ['Hello ', 'sports']

# %%
tweet.split('#')[-1]
# Out:
# 'sports'

# %%
dict1.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3', 'key4', 'key5', 'key6'])

# %%
dict1.items()
# Out:
# dict_items([('key1', 'value1'), ('key2', 'value2'), ('key3', 'value3'), ('key4', 'value4'), ('key5', 'value5'), ('key6', 'value6')])

# %%
mylist = [1,2,3]

# %%
last = mylist.pop()

# %%
last
# Out:
# 3

# %%
mylist
# Out:
# [1, 2]

# %%
mylist.append(3)
mylist
# Out:
# [1, 2, 3]

# %%
first = mylist.pop(0)

# %%
first
# Out:
# 1

# %%
mylist
# Out:
# [2, 3]

# %%
x in mylist
# Out:
# False

# %%
2 in mylist
# Out:
# True
