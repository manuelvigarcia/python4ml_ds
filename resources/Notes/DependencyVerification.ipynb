# %% [markdown]
# # Verify dependencies

# %%
import pandas
pandas.__version__
# Out:
# '3.0.1'

# %%
import numpy
numpy.__version__
# Out:
# '2.4.3'

# %%
import scipy
scipy.__version__
# Out:
# '1.17.1'

# %%
import sklearn
sklearn.__version__
# Out:
# '1.8.0'

# %%
import openpyxl
openpyxl.__version__
# Out:
# '3.1.5'

# %%
import sqlalchemy
sqlalchemy.__version__
# Out:
# '2.0.48'

# %%
import seaborn
seaborn.__version__
# Out:
# '0.13.2'

# %%
import lxml
lxml.__version__
# Out:
# '6.0.2'
